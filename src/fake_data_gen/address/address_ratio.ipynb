# %% [markdown]
# # 주별 주소 quota 계산
#
# `STATE_POPULATION_PCT` 와 `addr_to_df` 는 `address_utils` 로 이동됨. 이 노트북은 quota 계산 결과 확인 + 파서 동작 데모만 남긴다.

# %%
from fake_data_gen.address.address_utils import (
    STATE_POPULATION_PCT,
    addr_to_df,
    compute_state_quotas,
)

# %% [markdown]
# ## 1. 주별 quota — 합성하고 싶은 전체 주소 수에서 인구 비율로 분배

# %%
TOTAL_COUNT = 12797  # K-beauty 분석에 필요한 합성 주소 총 개수
quotas = compute_state_quotas(TOTAL_COUNT)
quotas

# %% [markdown]
# ## 2. `addr_to_df` 파서 동작 확인 — postcodebase 형식 주소 → DataFrame

# %%
sample_addresses = '''
445 S ARDMORE AVE LOS ANGELES CA 90020-3265 USA
900 E 12TH ST LOS ANGELES CA 90021-2202 USA
330 TEMPLE AVE LONG BEACH CA 90814-0703 USA
2701 S ROSEWOOD AVE SANTA ANA CA 92707-3678 USA
'''
addr_to_df(sample_addresses)

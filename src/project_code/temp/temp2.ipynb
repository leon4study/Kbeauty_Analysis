# %%
from bs4 import BeautifulSoup
import os, time

# %%
os.chdir("/Users/jun/GitStudy/Data_4/data/project5")

# %%
os.listdir()
# Out:
# ['beauty_of_Jo.html',
#  'reviews.csv',
#  '.DS_Store',
#  'beauty_of_Jo_files',
#  'Dr_jart_items.csv',
#  'cosrx_reviews.csv',
#  'beauty_of_Jo_2.html',
#  'Dr_jart_reviews.csv',
#  'beauty_of_Jo_2_files',
#  'cosrx_items.csv',
#  'items.csv']

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

try:
    # 2. 로컬 HTML 파일 열기
    local_html_path = os.path.abspath("beauty_of_Jo.html")  # HTML 파일의 절대 경로
    driver.get(f"file://{local_html_path}")
    price = None
    is_bundle = False

    try:
        # a-price-whole과 a-price-fraction에서 각각 가격 찾기 (CSS Selector로 변경)
        price_whole = driver.find_element(By.CSS_SELECTOR, "#corePrice_feature_div > div > div > div > div > span.a-price.a-text-normal.aok-align-center.reinventPriceAccordionT2 > span:nth-child(2) > span.a-price-whole").text
        price_fraction = driver.find_element(By.CSS_SELECTOR, "#corePrice_feature_div > div > div > div > div > span.a-price.a-text-normal.aok-align-center.reinventPriceAccordionT2 > span:nth-child(2) > span.a-price-fraction").text
        price = price_whole + "." + price_fraction
        print(price,"1")
    except:
        # 번들 가격일 가능성 있음
        try : 
            price = driver.execute_script("""
                var priceElement = document.querySelector("#corePrice_desktop > div > table > tbody > tr:nth-child(2) > td.a-span12 > span.a-price.a-text-price.a-size-medium.apexPriceToPay > span:nth-child(2)");
                return priceElement ? priceElement.textContent : null;
            """)
            if price:
                is_bundle = True
        except : 
            price = None



    # 결과 출력
    print("가격:", price)
    print("번들 여부:", is_bundle)
    
except Exception as e:
    print(f"오류 : {e}")

finally:
    # 4. WebDriver 종료
    time.sleep(1)
    #pass
    #driver.quit()
# Out:
# 가격: $47.99
# 번들 여부: True

# %%
driver = webdriver.Chrome()

try:
    # 2. 로컬 HTML 파일 열기
    local_html_path = os.path.abspath("beauty_of_Jo_2.html")  # HTML 파일의 절대 경로
    driver.get(f"file://{local_html_path}")
    price = None
    is_bundle = False

    try:
        # a-price-whole과 a-price-fraction에서 각각 가격 찾기 (CSS Selector로 변경)
        price_whole = driver.find_element(By.CSS_SELECTOR, "#corePrice_feature_div > div > div > div > div > span.a-price.a-text-normal.aok-align-center.reinventPriceAccordionT2 > span:nth-child(2) > span.a-price-whole").text
        price_fraction = driver.find_element(By.CSS_SELECTOR, "#corePrice_feature_div > div > div > div > div > span.a-price.a-text-normal.aok-align-center.reinventPriceAccordionT2 > span:nth-child(2) > span.a-price-fraction").text
        price = price_whole + "." + price_fraction
        print(price,"1")
    except:
        # 번들 가격일 가능성 있음
        try:
            price = driver.find_element(By.CSS_SELECTOR, "#corePrice_desktop > div > table > tbody > tr:nth-child(2) > td.a-span12 > span.a-price.a-text-price.a-size-medium.apexPriceToPay > span:nth-child(2)").text    
            is_bundle = True
        except :
            price = None


    # 결과 출력
    print("가격:", price)
    print("번들 여부:", is_bundle)
    
except Exception as e:
    print(f"오류 : {e}")

finally:
    # 4. WebDriver 종료
    time.sleep(1)
    #pass
    #driver.quit()
# Out:
# 16.58 1
# 가격: 16.58
# 번들 여부: False

# %%
try:
    # 로컬 HTML 파일 열기
    local_html_path = os.path.abspath("beauty_of_Jo.html")  # HTML 파일의 절대 경로
    driver.get(f"file://{local_html_path}")
    price = None
    is_bundle = False

    try:
        # JavaScript를 사용하여 가격 정보를 가져옴
        price = driver.execute_script("""
            let priceElement = document.querySelector("#corePrice_feature_div span.a-offscreen");
            return priceElement ? priceElement.innerText : null;
        """)
        
        if price:
            print(price, "1")
    except Exception as e:
        print(f"가격 찾는 도중 문제 발생 : {E}")
        
        else:
            # 번들 가격일 가능성 있음
            is_bundle = True
            price = driver.execute_script("""
                let bundleElement = document.querySelector("#corePrice_desktop > div > table > tbody > tr:nth-child(2) > td.a-span12 > span.a-price.a-text-price.a-size-medium.apexPriceToPay span.a-offscreen");
                return bundleElement ? bundleElement.innerText : null;
            """)
    except Exception as e:
        print(f"JavaScript를 사용해 가격 정보를 가져오지 못했습니다: {e}")

    # 결과 출력
    print("가격:", price)
    print("번들 여부:", is_bundle)

except Exception as e:
    print(f"오류: {e}")

finally:
    # WebDriver 종료
    time.sleep(1)
# Out:
# 오류: HTTPConnectionPool(host='localhost', port=64042): Max retries exceeded with url: /session/ba3a0b9bfd4ab936c18174019b3252bf/url (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x115a18dd0>: Failed to establish a new connection: [Errno 61] Connection refused'))

# %%
float("$47.99".strip("$"))
# Out:
# '47.99'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import os
import time

# WebDriver 초기화
driver = webdriver.Chrome()

try:
    # 2. 로컬 HTML 파일 열기
    local_html_path = os.path.abspath("Amazon_customer_reviews.html")  # HTML 파일의 절대 경로
    driver.get(f"file://{local_html_path}")

    # 3. 특정 리뷰 요소들 찾기
    reviews = driver.find_elements(By.CLASS_NAME, "review")  # 각 리뷰를 감싸는 컨테이너 클래스

    for idx, detail_review in enumerate(reviews, start=1):
        try:
            # (1) 리뷰 날짜 추출
            date_element = detail_review.find_elements(By.CSS_SELECTOR, "span[data-hook='review-date']")
            date = date_element[0].text if date_element else "No date"

            # (2) 리뷰 평점 추출
            rating_element = detail_review.find_elements(By.CLASS_NAME, "a-icon-alt")
            review_rating = rating_element[0].text if rating_element else "No rating"

            # (3) 리뷰 제목 추출
            title_element = detail_review.find_elements(By.CLASS_NAME, "review-title")
            review_title = title_element[0].text if title_element else "No title"

            # (4) 추출한 데이터 출력
            print(f"Review {idx}:")
            print(f"  Date: {date}")
            print(f"  Rating: {review_rating}")
            print(f"  Title: {review_title}")
            print("-" * 50)
        except Exception as e:
            print(f"Error processing review {idx}: {e}")

finally:
    # WebDriver 종료
    time.sleep(1)  # 필요한 경우만 사용
    #driver.quit()

# %% [markdown]
# ## csv drop duplicated

# %%
import pandas as pd
import os

# %%
os.chdir('/Users/jun/GitStudy/Data_4/Data/project5')
os.listdir()
# Out:
# ['Amazon.com_ K-beauty_ Beauty & Personal Care.html',
#  'reviews_202501131102.csv',
#  'reviews.csv',
#  '.DS_Store',
#  'reviews_202501131059.csv',
#  'Amazon.com_ K-beauty_ Beauty & Personal Care_files',
#  'items_df.csv',
#  'items.csv',
#  'items_202501131100.csv']

# %%
reviews_df = pd.read_csv("reviews_202501131102.csv",delimiter=",",index_col=False)
items_df = pd.read_csv("items_202501131100.csv",delimiter=",",index_col=False)

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14382 entries, 0 to 14381
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   review_num     14382 non-null  object
#  1   ASIN           14382 non-null  object
#  2   title          14382 non-null  object
#  3   date           14382 non-null  object
#  4   review_rating  14382 non-null  object
#  5   content        14357 non-null  object
# dtypes: object(6)
# memory usage: 674.3+ KB

# %%
items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ASIN                       383 non-null    object
#  1   title                      383 non-null    object
#  2   brand                      383 non-null    object
#  3   price                      381 non-null    float64
#  4   Special_Feature            383 non-null    object
#  5   total_star_mean            380 non-null    float64
#  6   detail_dict                383 non-null    object
#  7   best_sellers_rank_Feature  383 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 24.1+ KB

# %%
reviews_df = reviews_df.drop_duplicates().reset_index().drop(columns='index')
items_df = items_df.drop_duplicates().reset_index().drop(columns='index')

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14382 entries, 0 to 14381
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   review_num     14382 non-null  object
#  1   ASIN           14382 non-null  object
#  2   title          14382 non-null  object
#  3   date           14382 non-null  object
#  4   review_rating  14382 non-null  object
#  5   content        14357 non-null  object
# dtypes: object(6)
# memory usage: 674.3+ KB

# %%
reviews_df.to_csv('reviews.csv',index=False)
items_df.to_csv('items.csv',index=False)

# %% [markdown]
# ## 베스트셀러 카테고리 분류

# %%
items_df['best_sellers_rank_Feature'].apply(lambda x : x.split(" in ")[-1]).unique()
# Out:
# array(['Face Moisturizers', 'Facial Oils', 'Facial Serums', 'Hair Sprays',
#        'Eye Treatment Gels', 'Eye Treatment Creams',
#        'Facial Tinted Moisturizers', 'Facial Masks',
#        'Facial Toners & Astringents', 'Body Self-Tanners',
#        'Body Scrubs & Treatments', 'Facial Cleansing Washes', 'Eye Masks',
#        'Facial Skin Care Sets & Kits', 'Eye Wrinkle Pads & Patches',
#        'Eyelash Primers', 'Facial Night Creams', 'Hair Treatment Masks',
#        'Hair Straightening Irons', 'Eye Treatment Balms',
#        'Foundation Brushes', 'Vitamin D Supplements',
#        'Hair Regrowth Treatments', 'Sunscreens', 'Eye Treatment Serums',
#        'Skin Care Sets & Kits', 'Makeup Cleansing Oils', 'Body Butters',
#        'Facial Cleansing Cloths & Towelettes', 'Face Mists',
#        'Facial Sunscreens', 'Hair Brushes', 'Makeup Blenders & Sponges',
#        'Shampoo & Conditioner Sets', 'Makeup Cleansing Water',
# ...

# %%
result = (
    items_df['best_sellers_rank_Feature']
    .apply(lambda x: x.split(" in ")[-1])  # 원하는 카테고리 추출
    .value_counts()  # 각 카테고리별 개수 계산
    .reset_index()  # DataFrame으로 변환
)

result.columns = ['Category', 'Count']  # 컬럼 이름 설정
result
# Out:
#                              Category  Count
# 0                       Facial Serums     74
# 1                   Face Moisturizers     58
# 2             Facial Cleansing Washes     28
# 3                        Facial Masks     27
# 4         Facial Toners & Astringents     27
# ..                                ...    ...
# 61                       Body Lotions      1
# 62  Women's Disposable Shaving Razors      1
# 63                          Lip Gloss      1
# 64                         Foot Files      1
# 65     Face Highlighters & Luminizers      1
#
# [66 rows x 2 columns]

# %% [markdown]
# ## HTML 읽고 파싱

# %%
os.chdir("/Users/jun/GitStudy/Data_4/Data/project5")
os.listdir()
# Out:
# ['Amazon.com_ K-beauty_ Beauty & Personal Care.html',
#  'reviews_202501131102.csv',
#  'reviews.csv',
#  '.DS_Store',
#  'reviews_202501131059.csv',
#  'Amazon.com_ K-beauty_ Beauty & Personal Care_files',
#  'items_df.csv',
#  'items.csv',
#  'items_202501131100.csv']

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
driver = webdriver.Chrome()

try:
    # 2. 로컬 HTML 파일 열기
    local_html_path = os.path.abspath("Amazon.com_k-beauty.html")  # HTML 파일의 절대 경로
    driver.get(f"file://{local_html_path}")


    # 3. 특정 리뷰 요소들 찾기

    items = driver.find_elements(By.CSS_SELECTOR, '[role="listitem"]')
    print("\n", len(items), "\n")
    

finally:
    # 4. WebDriver 종료
    time.sleep(1)
    #pass
    #driver.quit()
# Out:
#  0

# %%
# 10월 총 매출 계산
total_revenue = df_10['price'].sum()

# 10월 일별 매출 계산
daily_revenue = df_10.groupby('date_ymd')['price'].sum()

# 10월 요일별 매출 계산
day_week_revenue = df_10.groupby('day_of_week')['price'].sum()

# 10월 TPM 매출 계산
TPM_revenue = df_10.groupby('TPM')['price'].sum()

# 결과 출력
print("10월 총 매출:", total_revenue)
print("\n10월 일별 매출:\n", daily_revenue)
print("\n10월 요일별 매출:\n", day_week_revenue)
print("\n10월 TPM별 매출:\n", TPM_revenue)

# 시각화
import seaborn as sns

# 1. 일별 매출 추이 시각화
plt.figure(figsize=(12, 6))
daily_revenue.sort_index().plot(kind='line', color='skyblue', alpha=0.8)
plt.title('"Daily Revenue in October"', fontsize=16)
plt.xlabel('date', fontsize=12)
plt.ylabel('Revenue', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 2. 요일별 매출 추이 시각화
plt.figure(figsize=(8, 5))
sns.barplot(x=day_week_revenue.index, y=day_week_revenue.values, palette='pastel')
plt.title('Weekly Revenue in October', fontsize=16)
plt.xlabel('Week', fontsize=12)
plt.ylabel('Revenue', fontsize=12)
plt.tight_layout()
plt.show()

# 3. TPM별 매출 추이 시각화
plt.figure(figsize=(8, 5))
sns.barplot(x=TPM_revenue.index, y=TPM_revenue.values, palette='muted')
plt.title('TPM Revenue in October', fontsize=16)
plt.xlabel('TPM', fontsize=12)
plt.ylabel('Revenue', fontsize=12)
plt.tight_layout()
plt.show()

# %%
def click_next_item_page(wait):
    try:
        # Next page 버튼 기다리기
        next_page_button = wait.until(
            EC.element_to_be_clickable((By.CSS_SELECTOR, 'li.s-list-item-margin-right-adjustment'))
        )
        # 버튼 클릭
        next_page_button.click()
        print("Successfully clicked the Next Item Page button.")
    except Exception as e:
        print(f"Error clicking Next Page button: {e}")

# %%
list1 = [1,2,3,4,5]
list1[1:]
# Out:
# [2, 3, 4, 5]

# %% [markdown]
# ## csv drop duplicated

# %%
import os
import pandas as pd

# %%
os.chdir("/Users/jun/GitStudy/Data_4/Data/project5")
os.listdir()
# Out:
# ['reviews.csv',
#  '.DS_Store',
#  'items_nail_tools.csv',
#  'reviews_Skin_Care.csv',
#  'reviews_Hair_Care_Products.csv',
#  'items_Hair_Care_Products.csv',
#  'reviews_Beauty_Tools_Accessories.csv',
#  'items_Makeup.csv',
#  'reviews_nail_tools.csv',
#  'reviews_fagrance.csv',
#  'items_Skin_Care.csv',
#  'reviews_Makeup.csv',
#  'items_Beauty_Tools_Accessories.csv',
#  'items.csv',
#  'items_fagrance.csv']

# %%
items_Skin_Care = pd.read_csv("items_Skin_Care.csv",delimiter=",",index_col=False)
item_skin_care2 = pd.read_csv("item_skin_care2.csv",delimiter=",",index_col=False)
items_skin_care3 = pd.read_csv("items_skin_care3.csv",delimiter=",",index_col=False)

reviews_Skin_Care = pd.read_csv("reviews_Skin_Care.csv",delimiter=",",index_col=False)
review_skin_care2 = pd.read_csv("review_skin_care2.csv",delimiter=",",index_col=False)
reviews_skin_care3 = pd.read_csv("reviews_skin_care3.csv",delimiter=",",index_col=False)

reviews_Hair_Care_Products_perfumes = pd.read_csv("reviews_Hair Care Products_perfumes.csv",delimiter=",",index_col=False)
items_Hair_Care_Products_perfumes = pd.read_csv("items_Hair Care Products_perfumes.csv",delimiter=",",index_col=False)

items_fagrance_nail = pd.read_csv("items_fagrance_nail.csv",delimiter=",",index_col=False)
reviews_fagrance_nail = pd.read_csv("reviews_fagrance_nail.csv",delimiter=",",index_col=False)

# %%
items_nail_tools = pd.read_csv("items_nail_tools.csv",delimiter=",",index_col=False)
reviews_nail_tools = pd.read_csv("reviews_nail_tools.csv",delimiter=",",index_col=False)

# %%
reviews_Beauty_Tools_Accessories = pd.read_csv("reviews_Beauty_Tools_Accessories.csv",delimiter=",",index_col=False)
items_Beauty_Tools_Accessories = pd.read_csv("items_Beauty_Tools_Accessories.csv",delimiter=",",index_col=False)

# %%
items_Skin_Care_df = items_Skin_Care.append(item_skin_care2).append(items_skin_care3)
items_Skin_Care_df = items_Skin_Care_df.drop_duplicates()

reviews_Skin_Care_df = reviews_Skin_Care.append(review_skin_care2).append(reviews_skin_care3)
reviews_Skin_Care_df = reviews_Skin_Care_df.drop_duplicates()
# Out:
# /var/folders/29/5wmqbm4j3x10qv5vgm_bm8f80000gn/T/ipykernel_71031/1644080276.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   items_Skin_Care_df = items_Skin_Care.append(item_skin_care2).append(items_skin_care3)
# /var/folders/29/5wmqbm4j3x10qv5vgm_bm8f80000gn/T/ipykernel_71031/1644080276.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   reviews_Skin_Care_df = reviews_Skin_Care.append(review_skin_care2).append(reviews_skin_care3)

# %%
items_Skin_Care_df.to_csv("items_Skin_Care.csv",index=False)
reviews_Skin_Care_df.to_csv("reviews_Skin_Care.csv",index=False)

# %%
pd.merge(reviews_Hair_Care_Products_perfumes,items_fagrance_nail,'outer',).T
# Out:
#                                                                         0     \
# review_num                                                     B000PI33IS__0
# ASIN                                                              B000PI33IS
# customer_id                                                   R3UCWCTNPLCCYU
# customer_name                                                        MiCo106
# title                      K I.C.O.N. Mane Control, Hairstyling Gel. Give...
# date                       Reviewed in the United States on September 9, ...
# review_rating                                             5.0 out of 5 stars
# content                                                             The best
# brand                                                                    NaN
# price                                                                    NaN
# global_rating_count                                                      NaN
# ...

# %%
# 두 데이터프레임 간의 완전한 행 비교
merged_df = items_nail_tools.merge(
    items_Beauty_Tools_Accessories,
    how="left",  # 기준 데이터프레임을 유지
    indicator=True
)

# `_merge` 컬럼에서 'left_only'만 선택 (겹치지 않는 행)
filtered_reviews = merged_df[merged_df["_merge"] == "left_only"].drop(columns=["_merge"])

# 결과 확인
filtered_reviews.to_csv("items_nail.csv",index=False)

# %%
items_Skin_Care = pd.read_csv("items_Skin_Care.csv",delimiter=",",index_col=False)

# %%
dict1 = {"a" : 1, "B" :2, "C" : 3}

# %%
dict1.values()
# Out:
# dict_values([1, 2, 3])

# %%
<img class="s-image" src="https://m.media-amazon.com/images/I/51kYy6KzwhL._AC_UL320_.jpg" srcset="https://m.media-amazon.com/images/I/51kYy6KzwhL._AC_UL320_.jpg 1x, https://m.media-amazon.com/images/I/51kYy6KzwhL._AC_UL480_QL65_.jpg 1.5x, https://m.media-amazon.com/images/I/51kYy6KzwhL._AC_UL640_QL65_.jpg 2x, https://m.media-amazon.com/images/I/51kYy6KzwhL._AC_UL800_QL65_.jpg 2.5x, https://m.media-amazon.com/images/I/51kYy6KzwhL._AC_UL960_QL65_.jpg 3x" alt="Beauty of Joseon [Serum line] Glow Deep Serum :Rice +Alpha-Arbutin (30ml) + Glow Serum : Propolis+Niacinamide (30ml)" aria-hidden="true" data-image-index="23" data-image-load="" data-image-latency="s-product-image" data-image-source-density="1">

# %%
"https://m.media-amazon.com/images/I/51kYy6KzwhL._AC_UL320_.jpg"
